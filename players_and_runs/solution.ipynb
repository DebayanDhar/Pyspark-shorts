# %%
>>> countries_df = spark.read.option("header",True).csv("workspace_debayan/datasets/countries_dataset.csv");
>>> countries_df.show();
+---+------------+
|SRT|     country|
+---+------------+
|IND|       India|
|AUS|   Australia|
|ENG|     England|
| SA|South Africa|
| NZ| New Zealand|
|PAK|    Pakistan|
| WI| West Indies|
| SL|   Sri Lanka|
|BAN|  Bangladesh|
|AFG| Afghanistan|
+---+------------+

>>> players_df = spark.read.option("header",True).csv("workspace_debayan/datasets/players_dataset.csv");
>>>
>>> players_df.show();
+--------------+-----+--------+
|        player| runs|50s/100s|
+--------------+-----+--------+
| DeVilliers-SL| 4867|   60/18|
|     Smith-ENG|14249|   95/39|
|      Root-AUS| 1639|   35/40|
|Williamson-BAN| 1415|   51/33|
|     Babar-PAK|12544|   94/34|
|     Sachin-WI|14224|   70/50|
|       Root-SA| 4564|   51/29|
|   Ponting-ENG| 7171|   70/50|
|       Root-SL| 8181|    99/3|
|      Root-BAN| 1162|   39/10|
|      Gayle-NZ| 6533|   70/50|
|    Sachin-PAK| 3078|    57/3|
| Williamson-NZ| 3890|   91/40|
|     Warner-SL| 2586|   34/20|
|    Sachin-AUS| 8913|   69/40|
|Williamson-AUS| 4731|   18/41|
|    Sachin-AFG| 3592|   98/32|
|Williamson-AFG| 1406|   95/13|
|     Gayle-AUS|13990|   17/25|
|     Babar-BAN|12005|    75/2|
+--------------+-----+--------+
only showing top 20 rows

>>>
>>> from pyspark.sql.functions import substring_index
>>>
>>> playerSplit_df = players_df.select("*",substring_index(players_df.player,'-',1).alias('player_name'),substring_index(players_df.player,'-',-1).alias('SRT'));
>>>
>>> playerSplit_df.show();
+--------------+-----+--------+-----------+---+
|        player| runs|50s/100s|player_name|SRT|
+--------------+-----+--------+-----------+---+
| DeVilliers-SL| 4867|   60/18| DeVilliers| SL|
|     Smith-ENG|14249|   95/39|      Smith|ENG|
|      Root-AUS| 1639|   35/40|       Root|AUS|
|Williamson-BAN| 1415|   51/33| Williamson|BAN|
|     Babar-PAK|12544|   94/34|      Babar|PAK|
|     Sachin-WI|14224|   70/50|     Sachin| WI|
|       Root-SA| 4564|   51/29|       Root| SA|
|   Ponting-ENG| 7171|   70/50|    Ponting|ENG|
|       Root-SL| 8181|    99/3|       Root| SL|
|      Root-BAN| 1162|   39/10|       Root|BAN|
|      Gayle-NZ| 6533|   70/50|      Gayle| NZ|
|    Sachin-PAK| 3078|    57/3|     Sachin|PAK|
| Williamson-NZ| 3890|   91/40| Williamson| NZ|
|     Warner-SL| 2586|   34/20|     Warner| SL|
|    Sachin-AUS| 8913|   69/40|     Sachin|AUS|
|Williamson-AUS| 4731|   18/41| Williamson|AUS|
|    Sachin-AFG| 3592|   98/32|     Sachin|AFG|
|Williamson-AFG| 1406|   95/13| Williamson|AFG|
|     Gayle-AUS|13990|   17/25|      Gayle|AUS|
|     Babar-BAN|12005|    75/2|      Babar|BAN|
+--------------+-----+--------+-----------+---+
only showing top 20 rows

>>>
>>>
>>>
>>>
>>> playerAndRunsSplit_df =  playerSplit_df.select("*",substring_index("50s/100s",'/',1).alias('runs_50s'),substring_index("50s/100s",'/',-1).alias('runs_100s'));
>>>
>>> playerAndRunsSplit_df.show();
+--------------+-----+--------+-----------+---+--------+---------+
|        player| runs|50s/100s|player_name|SRT|runs_50s|runs_100s|
+--------------+-----+--------+-----------+---+--------+---------+
| DeVilliers-SL| 4867|   60/18| DeVilliers| SL|      60|       18|
|     Smith-ENG|14249|   95/39|      Smith|ENG|      95|       39|
|      Root-AUS| 1639|   35/40|       Root|AUS|      35|       40|
|Williamson-BAN| 1415|   51/33| Williamson|BAN|      51|       33|
|     Babar-PAK|12544|   94/34|      Babar|PAK|      94|       34|
|     Sachin-WI|14224|   70/50|     Sachin| WI|      70|       50|
|       Root-SA| 4564|   51/29|       Root| SA|      51|       29|
|   Ponting-ENG| 7171|   70/50|    Ponting|ENG|      70|       50|
|       Root-SL| 8181|    99/3|       Root| SL|      99|        3|
|      Root-BAN| 1162|   39/10|       Root|BAN|      39|       10|
|      Gayle-NZ| 6533|   70/50|      Gayle| NZ|      70|       50|
|    Sachin-PAK| 3078|    57/3|     Sachin|PAK|      57|        3|
| Williamson-NZ| 3890|   91/40| Williamson| NZ|      91|       40|
|     Warner-SL| 2586|   34/20|     Warner| SL|      34|       20|
|    Sachin-AUS| 8913|   69/40|     Sachin|AUS|      69|       40|
|Williamson-AUS| 4731|   18/41| Williamson|AUS|      18|       41|
|    Sachin-AFG| 3592|   98/32|     Sachin|AFG|      98|       32|
|Williamson-AFG| 1406|   95/13| Williamson|AFG|      95|       13|
|     Gayle-AUS|13990|   17/25|      Gayle|AUS|      17|       25|
|     Babar-BAN|12005|    75/2|      Babar|BAN|      75|        2|
+--------------+-----+--------+-----------+---+--------+---------+
only showing top 20 rows

>>>
>>>
>>>
>>> consolidated_df = playerAndRunsSplit_df.join(countries_df, playerAndRunsSplit_df.SRT == countries_df.SRT);
>>>
>>> consolidated_df.show();
+--------------+-----+--------+-----------+---+--------+---------+---+------------+
|        player| runs|50s/100s|player_name|SRT|runs_50s|runs_100s|SRT|     country|
+--------------+-----+--------+-----------+---+--------+---------+---+------------+
| DeVilliers-SL| 4867|   60/18| DeVilliers| SL|      60|       18| SL|   Sri Lanka|
|     Smith-ENG|14249|   95/39|      Smith|ENG|      95|       39|ENG|     England|
|      Root-AUS| 1639|   35/40|       Root|AUS|      35|       40|AUS|   Australia|
|Williamson-BAN| 1415|   51/33| Williamson|BAN|      51|       33|BAN|  Bangladesh|
|     Babar-PAK|12544|   94/34|      Babar|PAK|      94|       34|PAK|    Pakistan|
|     Sachin-WI|14224|   70/50|     Sachin| WI|      70|       50| WI| West Indies|
|       Root-SA| 4564|   51/29|       Root| SA|      51|       29| SA|South Africa|
|   Ponting-ENG| 7171|   70/50|    Ponting|ENG|      70|       50|ENG|     England|
|       Root-SL| 8181|    99/3|       Root| SL|      99|        3| SL|   Sri Lanka|
|      Root-BAN| 1162|   39/10|       Root|BAN|      39|       10|BAN|  Bangladesh|
|      Gayle-NZ| 6533|   70/50|      Gayle| NZ|      70|       50| NZ| New Zealand|
|    Sachin-PAK| 3078|    57/3|     Sachin|PAK|      57|        3|PAK|    Pakistan|
| Williamson-NZ| 3890|   91/40| Williamson| NZ|      91|       40| NZ| New Zealand|
|     Warner-SL| 2586|   34/20|     Warner| SL|      34|       20| SL|   Sri Lanka|
|    Sachin-AUS| 8913|   69/40|     Sachin|AUS|      69|       40|AUS|   Australia|
|Williamson-AUS| 4731|   18/41| Williamson|AUS|      18|       41|AUS|   Australia|
|    Sachin-AFG| 3592|   98/32|     Sachin|AFG|      98|       32|AFG| Afghanistan|
|Williamson-AFG| 1406|   95/13| Williamson|AFG|      95|       13|AFG| Afghanistan|
|     Gayle-AUS|13990|   17/25|      Gayle|AUS|      17|       25|AUS|   Australia|
|     Babar-BAN|12005|    75/2|      Babar|BAN|      75|        2|BAN|  Bangladesh|
+--------------+-----+--------+-----------+---+--------+---------+---+------------+
only showing top 20 rows

>>>
>>>
>>> refined_df = consolidated_df.selectExpr("cast (player_name as String) player_name","cast (country as String) country_name","cast (runs as bigint) runs","cast (runs_50s as int) runs_50s","cast (runs_100s as int) runs_100s");
>>>
>>>
>>> refined_df.show();
+-----------+------------+-----+--------+---------+
|player_name|country_name| runs|runs_50s|runs_100s|
+-----------+------------+-----+--------+---------+
| DeVilliers|   Sri Lanka| 4867|      60|       18|
|      Smith|     England|14249|      95|       39|
|       Root|   Australia| 1639|      35|       40|
| Williamson|  Bangladesh| 1415|      51|       33|
|      Babar|    Pakistan|12544|      94|       34|
|     Sachin| West Indies|14224|      70|       50|
|       Root|South Africa| 4564|      51|       29|
|    Ponting|     England| 7171|      70|       50|
|       Root|   Sri Lanka| 8181|      99|        3|
|       Root|  Bangladesh| 1162|      39|       10|
|      Gayle| New Zealand| 6533|      70|       50|
|     Sachin|    Pakistan| 3078|      57|        3|
| Williamson| New Zealand| 3890|      91|       40|
|     Warner|   Sri Lanka| 2586|      34|       20|
|     Sachin|   Australia| 8913|      69|       40|
| Williamson|   Australia| 4731|      18|       41|
|     Sachin| Afghanistan| 3592|      98|       32|
| Williamson| Afghanistan| 1406|      95|       13|
|      Gayle|   Australia|13990|      17|       25|
|      Babar|  Bangladesh|12005|      75|        2|
+-----------+------------+-----+--------+---------+
only showing top 20 rows

>>>
>>>
>>> refined_df.createOrReplaceTempView("TempTAB")                                                                                                                       >>>
>>>
>>> output_df = spark.sql("select player_name,country_name,runs,runs_50s + runs_100s as total_50s_100s from TempTAB where runs_50s + runs_100s > 90 order by country_name");
>>>
>>>
>>> output_df.show(output_df.count());
+-----------+------------+-----+--------------+
|player_name|country_name| runs|total_50s_100s|
+-----------+------------+-----+--------------+
|      Kohli| Afghanistan| 1523|           110|
| DeVilliers| Afghanistan| 2286|           102|
| Williamson| Afghanistan| 1406|           108|
|      Babar| Afghanistan|13384|           122|
|      Gayle| Afghanistan|13989|           112|
|     Sachin| Afghanistan| 3592|           130|
|     Sachin|   Australia| 1592|           109|
|     Sachin|   Australia| 8913|           109|
|      Smith|   Australia| 3777|            96|
|    Ponting|     England| 7171|           120|
|      Smith|     England|14249|           134|
| Williamson|     England|14514|           142|
|      Smith|       India| 1463|           141|
|      Kohli|       India|10474|           131|
| Williamson| New Zealand| 3890|           131|
|       Root| New Zealand| 3645|           131|
|      Gayle| New Zealand| 6533|           120|
|     Warner| New Zealand|14858|           108|
|      Babar|    Pakistan| 1237|           131|
|    Ponting|    Pakistan|10078|           142|
| Williamson|    Pakistan| 3927|           142|
|      Kohli|    Pakistan|13807|           126|
|      Babar|    Pakistan|12544|           128|
|       Root|   Sri Lanka| 8181|           102|
|     Sachin| West Indies|14224|           120|
|      Babar| West Indies| 3092|           131|
|     Sachin| West Indies| 2279|            96|
+-----------+------------+-----+--------------+

>>>
>>>
>>>
>>> output_df.write.csv("workspace_debayan/datasets/result_dataset.csv")
>>>
>>>
